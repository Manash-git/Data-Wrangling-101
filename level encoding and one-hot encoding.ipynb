# %% [markdown]
# ## Label Encoding with all columns at a time

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import numpy as np

# %%
data = pd.read_csv('dataset/carprice.csv')
data
# Out:
#          Car Model  Mileage  Sell Price  Age
# 0           BMW X5    69000       18000    6
# 1           BMW X5    35000       34000    3
# 2           BMW X5    57000       26100    5
# 3           BMW X5    22500       40000    2
# 4           BMW X5    46000       31500    4
# 5             Audi    59000       29400    5
# 6             Audi    52000       32000    5
# 7             Audi    72000       19300    6
# 8             Audi    91000       12000    8
# 9   Mercedez Benz     67000       22000    6
# 10  Mercedez Benz     83000       20000    7
# 11  Mercedez Benz     79000       21000    7
# 12  Mercedez Benz     59000       33000    5
# 13          Toyota    51000       42000    4
# 14          Toyota    65000       32000    7
# 15          Toyota    39000       55000    5
# 16            Audi    59000       29400    5
# 17            Audi    52000       32000    5
# 18          BMW X5    69999        1855   10
# 19          BMW X5    35000       34000    3
# ...

# %%
le= LabelEncoder()

# %%
data['Car Model encode'] = le.fit_transform(data['Car Model'])
data
# Out:
#          Car Model  Mileage  Sell Price  Age  Car Model encode
# 0           BMW X5    69000       18000    6                 1
# 1           BMW X5    35000       34000    3                 1
# 2           BMW X5    57000       26100    5                 1
# 3           BMW X5    22500       40000    2                 1
# 4           BMW X5    46000       31500    4                 1
# 5             Audi    59000       29400    5                 0
# 6             Audi    52000       32000    5                 0
# 7             Audi    72000       19300    6                 0
# 8             Audi    91000       12000    8                 0
# 9   Mercedez Benz     67000       22000    6                 2
# 10  Mercedez Benz     83000       20000    7                 2
# 11  Mercedez Benz     79000       21000    7                 2
# 12  Mercedez Benz     59000       33000    5                 2
# 13          Toyota    51000       42000    4                 3
# ...

# %%
data.sort_values(by =['Car Model encode'])
# Out:
#          Car Model  Mileage  Sell Price  Age  Car Model encode
# 5             Audi    59000       29400    5                 0
# 6             Audi    52000       32000    5                 0
# 7             Audi    72000       19300    6                 0
# 8             Audi    91000       12000    8                 0
# 17            Audi    52000       32000    5                 0
# 16            Audi    59000       29400    5                 0
# 0           BMW X5    69000       18000    6                 1
# 1           BMW X5    35000       34000    3                 1
# 2           BMW X5    57000       26100    5                 1
# 3           BMW X5    22500       40000    2                 1
# 4           BMW X5    46000       31500    4                 1
# 19          BMW X5    35000       34000    3                 1
# 18          BMW X5    69999        1855   10                 1
# 11  Mercedez Benz     79000       21000    7                 2
# ...

# %% [markdown]
# ## Car Prices One Hot encoding

# %%
data
# Out:
#          Car Model  Mileage  Sell Price  Age  Car Model encode
# 0           BMW X5    69000       18000    6                 1
# 1           BMW X5    35000       34000    3                 1
# 2           BMW X5    57000       26100    5                 1
# 3           BMW X5    22500       40000    2                 1
# 4           BMW X5    46000       31500    4                 1
# 5             Audi    59000       29400    5                 0
# 6             Audi    52000       32000    5                 0
# 7             Audi    72000       19300    6                 0
# 8             Audi    91000       12000    8                 0
# 9   Mercedez Benz     67000       22000    6                 2
# 10  Mercedez Benz     83000       20000    7                 2
# 11  Mercedez Benz     79000       21000    7                 2
# 12  Mercedez Benz     59000       33000    5                 2
# 13          Toyota    51000       42000    4                 3
# ...

# %%
dummies = pd.get_dummies(df['Car Model'])
dummies

# %% [markdown]
# ## concatanation

# %%
merged = pd.concat([data, dummies], axis= 'columns')
merged
# Out:
#          Car Model  Mileage  Sell Price  Age  Car Model encode  0  1  2  3
# 0           BMW X5    69000       18000    6                 1  0  1  0  0
# 1           BMW X5    35000       34000    3                 1  0  1  0  0
# 2           BMW X5    57000       26100    5                 1  0  1  0  0
# 3           BMW X5    22500       40000    2                 1  0  1  0  0
# 4           BMW X5    46000       31500    4                 1  0  1  0  0
# 5             Audi    59000       29400    5                 0  1  0  0  0
# 6             Audi    52000       32000    5                 0  1  0  0  0
# 7             Audi    72000       19300    6                 0  1  0  0  0
# 8             Audi    91000       12000    8                 0  1  0  0  0
# 9   Mercedez Benz     67000       22000    6                 2  0  0  1  0
# 10  Mercedez Benz     83000       20000    7                 2  0  0  1  0
# ...

# %%
final = merged.drop(['Car Model'], axis='columns')
final
# Out:
#     Mileage  Sell Price  Age  Car Model encode  0  1  2  3
# 0     69000       18000    6                 1  0  1  0  0
# 1     35000       34000    3                 1  0  1  0  0
# 2     57000       26100    5                 1  0  1  0  0
# 3     22500       40000    2                 1  0  1  0  0
# 4     46000       31500    4                 1  0  1  0  0
# 5     59000       29400    5                 0  1  0  0  0
# 6     52000       32000    5                 0  1  0  0  0
# 7     72000       19300    6                 0  1  0  0  0
# 8     91000       12000    8                 0  1  0  0  0
# 9     67000       22000    6                 2  0  0  1  0
# 10    83000       20000    7                 2  0  0  1  0
# 11    79000       21000    7                 2  0  0  1  0
# 12    59000       33000    5                 2  0  0  1  0
# 13    51000       42000    4                 3  0  0  0  1
# 14    65000       32000    7                 3  0  0  0  1
# ...
